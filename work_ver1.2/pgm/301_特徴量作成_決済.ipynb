# %% [markdown]
# # 基本設定

# %%
import setting

import pandas as pd
import numpy as np
import math
import pathlib as Path

import scipy as sc
import sklearn
import pickle
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sb
sb.set(font='IPAexGothic')

# データ格納先設定
data_path = Path.Path('../data')
# 接頭辞
prefix = 'ana301'

# %% [markdown]
# # データ抽出
# > 軸データ（ana103_base_smpl.pkl）\
# > 決済加工情報（ana201_fix_rec.pkl）

# %%
# 軸データ
base = pd.read_pickle(data_path / 'ana103_base_smpl.pkl')
# 決済情報
df = pd.read_pickle(data_path / 'ana201_fix_rec.pkl')

# %%
base.shape
# Out:
# (3364, 3)

# %% [markdown]
# # データ結合

# %%
# 軸データに外部結合
_df = base.merge(df.reset_index(), on='customer_id_nys', how='left')

# %%
_df['customer_id_nys'].nunique()
# Out:
# 3364

# %% [markdown]
# # 特徴量作成

# %%
# 観測期間の抽出
_rec = _df[_df['sales_ym'].isin(setting.ym_bef.values())]
_rec
# Out:
#       customer_id_nys  flg_sts  flg_train sales_ym  sales_date  sum_amt  \
# 0      CS005415000212        0          1   201701           3      188
# 1      CS005415000212        0          1   201701          99      188
# 2      CS005415000212        0          1   201703           1      338
# 3      CS005415000212        0          1   201703           3      526
# 4      CS005415000212        0          1   201703          99      864
# ...               ...      ...        ...      ...         ...      ...
# 43209  CS014414000069        0          0   201704          99      273
# 43210  CS014414000069        0          0   201706           3      455
# 43211  CS014414000069        0          0   201706          99      455
# 43212  CS014414000069        0          0   201712           6      335
# 43213  CS014414000069        0          0   201712          99      335
#
#        sum_qnt
# 0            2
# 1            2
# 2            2
# 3            2
# 4            4
# ...        ...
# 43209        2
# 43210        2
# 43211        2
# 43212        2
# 43213        2
#
# [16256 rows x 7 columns]

# %% [markdown]
# ## 顧客×購入曜日（全体）ごとに集約統計量を計算

# %%
# 集約関数の定義
def f_grp(x, col):
    d = {}
    # 平均値
    d['FTR_avg_%s' % col] = x[col].mean()
    # 合計
    d['FTR_sum_%s' % col] = x[col].sum()
    # 最小
    d['FTR_min_%s' % col] = x[col].min()
    # 最大
    d['FTR_max_%s' % col] = x[col].max()
    # レンジ
    d['FTR_rng_%s' % col] = x[col].max() - x[col].min()
    # 標準偏差
    d['FTR_std_%s' % col] = x[col].std()
    
    return d

# %%
ftr_rec = _rec.groupby(['customer_id_nys', 'sales_date']).apply(
    
    lambda x : pd.Series(f_grp(x, 'sum_amt') | f_grp(x, 'sum_qnt'))
    
).fillna(0)

# %%
# 顧客単位に横持変換
_tmp = ftr_rec.unstack().fillna(0)

# %%
# 列名を整理
_tmp.columns = ['_'.join([i, str(j)]) for i, j in _tmp.columns]
_tmp
# Out:
#                  FTR_avg_sum_amt_0  FTR_avg_sum_amt_1  FTR_avg_sum_amt_2  \
# customer_id_nys
# CS001115000010                 0.0                0.0                0.0
# CS001205000004                 0.0                0.0                0.0
# CS001214000009              1474.5                0.0                0.0
# CS001214000048                 0.0                0.0                0.0
# CS001215000005               286.0                0.0                0.0
# ...                            ...                ...                ...
# CS043415000010              1285.0                0.0             1328.0
# CS043514000010                 0.0                0.0                0.0
# CS044414000004               228.0                0.0                0.0
# CS044415000001                 0.0                0.0                0.0
# CS044415000006                 0.0                0.0                0.0
#
#                  FTR_avg_sum_amt_3  FTR_avg_sum_amt_4  FTR_avg_sum_amt_5  \
# customer_id_nys
# CS001115000010              2320.0                0.0                0.0
# CS001205000004               850.0                0.0                0.0
# CS001214000009               198.0                0.0                0.0
# CS001214000048               283.0                0.0                0.0
# CS001215000005                 0.0                0.0                0.0
# ...                            ...                ...                ...
# CS043415000010                 0.0                0.0                0.0
# CS043514000010                 0.0             1100.0                0.0
# CS044414000004                 0.0                0.0                0.0
# CS044415000001              2535.0                0.0                0.0
# CS044415000006                 0.0                0.0                0.0
#
#                  FTR_avg_sum_amt_6  FTR_avg_sum_amt_99  FTR_sum_sum_amt_0  \
# customer_id_nys
# CS001115000010                 0.0              2320.0                0.0
# CS001205000004                 0.0               850.0                0.0
# CS001214000009                 0.0              1573.5             2949.0
# CS001214000048                 0.0               283.0                0.0
# CS001215000005                 0.0               286.0              286.0
# ...                            ...                 ...                ...
# CS043415000010                 0.0              1306.5             1285.0
# CS043514000010                 0.0              1100.0                0.0
# CS044414000004                 0.0               228.0              228.0
# CS044415000001                 0.0              2535.0                0.0
# CS044415000006              1418.0              1418.0                0.0
#
#                  FTR_sum_sum_amt_1  ...  FTR_rng_sum_qnt_6  \
# customer_id_nys                     ...
# CS001115000010                 0.0  ...                0.0
# CS001205000004                 0.0  ...                0.0
# CS001214000009                 0.0  ...                0.0
# CS001214000048                 0.0  ...                0.0
# CS001215000005                 0.0  ...                0.0
# ...                            ...  ...                ...
# CS043415000010                 0.0  ...                0.0
# CS043514000010                 0.0  ...                0.0
# CS044414000004                 0.0  ...                0.0
# CS044415000001                 0.0  ...                0.0
# CS044415000006                 0.0  ...                0.0
#
#                  FTR_rng_sum_qnt_99  FTR_std_sum_qnt_0  FTR_std_sum_qnt_1  \
# customer_id_nys
# CS001115000010                  0.0           0.000000                0.0
# CS001205000004                  0.0           0.000000                0.0
# CS001214000009                  1.0           0.707107                0.0
# CS001214000048                  0.0           0.000000                0.0
# CS001215000005                  0.0           0.000000                0.0
# ...                             ...                ...                ...
# CS043415000010                  0.0           0.000000                0.0
# CS043514000010                  0.0           0.000000                0.0
# CS044414000004                  0.0           0.000000                0.0
# CS044415000001                  0.0           0.000000                0.0
# CS044415000006                  0.0           0.000000                0.0
#
#                  FTR_std_sum_qnt_2  FTR_std_sum_qnt_3  FTR_std_sum_qnt_4  \
# customer_id_nys
# CS001115000010                 0.0                0.0                0.0
# CS001205000004                 0.0                0.0                0.0
# CS001214000009                 0.0                0.0                0.0
# CS001214000048                 0.0                0.0                0.0
# CS001215000005                 0.0                0.0                0.0
# ...                            ...                ...                ...
# CS043415000010                 0.0                0.0                0.0
# CS043514000010                 0.0                0.0                0.0
# CS044414000004                 0.0                0.0                0.0
# CS044415000001                 0.0                0.0                0.0
# CS044415000006                 0.0                0.0                0.0
#
#                  FTR_std_sum_qnt_5  FTR_std_sum_qnt_6  FTR_std_sum_qnt_99
# customer_id_nys
# CS001115000010                 0.0                0.0            0.000000
# CS001205000004                 0.0                0.0            0.000000
# CS001214000009                 0.0                0.0            0.707107
# CS001214000048                 0.0                0.0            0.000000
# CS001215000005                 0.0                0.0            0.000000
# ...                            ...                ...                 ...
# CS043415000010                 0.0                0.0            0.000000
# CS043514000010                 0.0                0.0            0.000000
# CS044414000004                 0.0                0.0            0.000000
# CS044415000001                 0.0                0.0            0.000000
# CS044415000006                 0.0                0.0            0.000000
#
# [3364 rows x 96 columns]

# %% [markdown]
# # データ保存

# %%
_tmp.to_pickle(data_path / ('%s_ftr_rec.pkl' % prefix))
